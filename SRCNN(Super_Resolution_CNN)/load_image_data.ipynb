# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import tensorflow as tf
import glob
image_name=[]
for i in glob.glob("./Train/*.bmp"):#load image data
    n=plt.imread(i)
    image_name.append(n)

def resize_image(image,size):
    init_op = (tf.global_variables_initializer())
    with tf.Session() as sess:
        sess.run(init_op)
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(coord=coord)
        image2=tf.image.resize_images(images=image,size=size)
    return image2

for i in range(len(image_name)):
    resized_image=resize_image(image_name[i],[33,33])
    print(resized_image.shape)
#      Image.fromarray(np.asarray(image)).show()
# Out:
# C:\Users\Robotmedia9\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
# (33, 33, 3)
