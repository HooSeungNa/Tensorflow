# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import glob
from read_xml import*
import tensorflow as tf
# Out:
# C:\Users\Robotmedia9\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
size=224
X = tf.placeholder(tf.float32, [None, size,size,3]) # image data 
W1 = tf.Variable(tf.random_normal([7, 7, 3, 96], stddev=0.01),name='W1')
W2 = tf.Variable(tf.random_normal([5, 5, 96, 256], stddev=0.01),name='W2')
W3 = tf.Variable(tf.random_normal([3, 3, 256, 384], stddev=0.01),name='W3')
W4 = tf.Variable(tf.random_normal([3, 3, 384, 384], stddev=0.01),name='W4')
W5 = tf.Variable(tf.random_normal([3, 3, 384, 256], stddev=0.01),name='W5')
 


L1 = tf.nn.conv2d(X, W1, strides=[1, 2, 2, 1], padding='SAME')
L1 = tf.nn.relu(L1)
#LRN 넣기
L1 = tf.nn.max_pool(L1, ksize=[1, 3, 3, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

L2 = tf.nn.conv2d(L1, W2, strides=[1, 2, 2, 1], padding='SAME')
L2 = tf.nn.relu(L2)
#LRN 넣기
L2 = tf.nn.max_pool(L2, ksize=[1, 3, 3, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

L3 = tf.nn.conv2d(L2, W3, strides=[1, 1, 1, 1], padding='SAME')
L3 = tf.nn.relu(L3)

L4 = tf.nn.conv2d(L3, W4, strides=[1, 1, 1, 1], padding='SAME')
L4 = tf.nn.relu(L4)

L5 = tf.nn.conv2d(L4, W5, strides=[1, 1, 1, 1], padding='SAME')
L5 = tf.nn.relu(L5)

# %%
print(L5)
# Out:
# Tensor("Relu_4:0", shape=(?, 14, 14, 256), dtype=float32)

# %%
image_data=[]
image_data=read_image()
# image_data=cv2.imread("D:\PASCAL\VOCdevkit\VOC2012\JPEGImages/2007_000027.jpg",cv2.IMREAD_COLOR)

# %%
sess=tf.Session()
saver = tf.train.Saver({"W1":W1,"W2":W2,"W3":W3,"W4":W4,"W5":W5})
saver.restore(sess, "./checkpoint/sppnet_trained_0070.ckpt")#load training data
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoint/sppnet_trained_0070.ckpt
# W1 : [[[[-0.06479301 -0.07185461 -0.06309287 ... -0.0408775  -0.0695301
#     -0.05189398]
#    [-0.02854208 -0.06887428 -0.05291032 ... -0.07973412 -0.05478656
#     -0.05243146]
#    [-0.05571016 -0.05655868 -0.05948252 ... -0.03382749 -0.06181584
#     -0.04542318]]
#
#   [[-0.04753726 -0.07808983 -0.07109114 ... -0.05055545 -0.05579372
#     -0.06345464]
#    [-0.0439842  -0.0740972  -0.05081635 ... -0.07162498 -0.05119932
#     -0.07166295]
#    [-0.05662998 -0.05825284 -0.06054119 ... -0.08441267 -0.05957964
#     -0.06321356]]
#
#   [[-0.0527623  -0.06100205 -0.05083722 ... -0.07317793 -0.07730954
#     -0.06048567]
#    [-0.04201294 -0.05867869 -0.06129504 ... -0.06164214 -0.06542012
#     -0.06289586]
#    [-0.04071009 -0.06254079 -0.06084927 ... -0.07241112 -0.068876
#     -0.06245252]]
#
#   ...
#
#   [[-0.05366499 -0.0610461  -0.06541366 ... -0.04070158 -0.05307648
#     -0.04272733]
#    [-0.06930017 -0.07060302 -0.0680651  ... -0.0265261  -0.0584074
#     -0.05220065]
#    [-0.0672454  -0.07016946 -0.05651564 ... -0.04555228 -0.06545135
#     -0.04825826]]
#
#   [[-0.04693358 -0.04400827 -0.06046398 ... -0.04037241 -0.05998747
#     -0.07637043]
#    [-0.08487519 -0.06069559 -0.05633162 ... -0.05373026 -0.04676961
#     -0.07316698]
#    [-0.06394529 -0.05613769 -0.07571435 ... -0.03627551 -0.04987178
#     -0.0584395 ]]
#
#   [[-0.05778975 -0.07561515 -0.06816905 ... -0.03670994 -0.06118196
#     -0.04582004]
#    [-0.06978443 -0.06137542 -0.06000643 ... -0.0476028  -0.04633449
#     -0.07475546]
#    [-0.06689154 -0.05247648 -0.07473084 ... -0.0422055  -0.07040302
#     -0.07179634]]]
#
#
#  [[[-0.06650045 -0.0481754  -0.04990881 ... -0.06239771 -0.06906506
#     -0.07617808]
#    [-0.08597985 -0.07245559 -0.05406321 ... -0.06566405 -0.073283
#     -0.05596647]
#    [-0.04260411 -0.05034662 -0.06334468 ... -0.04309871 -0.06092331
#     -0.06361874]]
#
#   [[-0.03436311 -0.04554335 -0.06347344 ... -0.07198622 -0.0755677
#     -0.05507873]
#    [-0.05413249 -0.05915844 -0.05424956 ... -0.05948667 -0.07334292
#     -0.04214814]
#    [-0.05183222 -0.04207099 -0.04415448 ... -0.07739256 -0.05387886
#     -0.06839173]]
#
#   [[-0.05260966 -0.06217533 -0.04973054 ... -0.05011423 -0.05998281
#     -0.07273825]
#    [-0.03181197 -0.04187187 -0.06979445 ... -0.06520776 -0.04854099
#     -0.05753004]
#    [-0.02088219 -0.06022844 -0.05129471 ... -0.06302784 -0.07469191
#     -0.07086023]]
#
#   ...
#
#   [[-0.0799352  -0.06600598 -0.05381928 ... -0.04064779 -0.06349204
#     -0.06039268]
#    [-0.06631333 -0.04354286 -0.06352822 ... -0.0555164  -0.06160136
#     -0.06326758]
#    [-0.08745947 -0.05660423 -0.06366721 ... -0.043793   -0.06620078
#     -0.07121778]]
#
#   [[-0.05366779 -0.07108165 -0.08742932 ... -0.05484172 -0.06704497
#     -0.07679439]
#    [-0.05635004 -0.04102864 -0.0656591  ... -0.05508496 -0.07093198
#     -0.06606989]
#    [-0.07268412 -0.08169907 -0.06612905 ... -0.06029074 -0.07638644
#     -0.03845837]]
#
#   [[-0.07759942 -0.04140078 -0.0451753  ... -0.0674284  -0.05553124
#     -0.04995433]
#    [-0.054145   -0.04980474 -0.05693071 ... -0.0664558  -0.05048003
#     -0.05388511]
#    [-0.06828962 -0.06587892 -0.07396761 ... -0.06096179 -0.05643919
#     -0.06351493]]]
#
#
#  [[[-0.06576853 -0.06110222 -0.06225329 ... -0.03716472 -0.07344045
#     -0.05814561]
#    [-0.05261591 -0.07670344 -0.060856   ... -0.04668745 -0.05136343
#     -0.05687763]
#    [-0.0753481  -0.0724791  -0.06184887 ... -0.03825358 -0.05883506
#     -0.06584202]]
#
#   [[-0.02742152 -0.04546254 -0.05965567 ... -0.04125666 -0.0678471
#     -0.07510151]
#    [-0.06673787 -0.06752056 -0.06656489 ... -0.07384706 -0.05736879
#     -0.07025883]
#    [-0.05063749 -0.05896998 -0.05258882 ... -0.04614232 -0.05938406
#     -0.06953637]]
#
#   [[-0.05096115 -0.05033569 -0.06372461 ... -0.05119428 -0.06035294
#     -0.06941158]
#    [-0.06339508 -0.0583451  -0.0464181  ... -0.08164813 -0.0456579
#     -0.06991223]
#    [-0.0526882  -0.06177334 -0.04474191 ... -0.03383533 -0.06308473
#     -0.05735654]]
#
#   ...
#
#   [[-0.06711894 -0.05711245 -0.06214008 ... -0.04710532 -0.05883969
#     -0.0636766 ]
#    [-0.04933289 -0.04828305 -0.05940862 ... -0.04955043 -0.05531473
#     -0.05730581]
#    [-0.06600921 -0.06197229 -0.06730539 ... -0.06437166 -0.06037566
#     -0.07006519]]
#
#   [[-0.06487891 -0.06750806 -0.06086561 ... -0.04891226 -0.07218293
#     -0.08403765]
#    [-0.05176173 -0.05159294 -0.05200645 ... -0.04515402 -0.06878465
#     -0.04366276]
#    [-0.09858748 -0.04648211 -0.06289648 ... -0.03412134 -0.04786345
#     -0.06775974]]
#
#   [[-0.0646298  -0.06425074 -0.03222955 ... -0.03876125 -0.06901278
#     -0.06249034]
#    [-0.08098258 -0.06750109 -0.06405261 ... -0.03887434 -0.06761876
#     -0.07751215]
#    [-0.06556491 -0.07267823 -0.04554255 ... -0.03585999 -0.0598734
#     -0.06029914]]]
#
#
#  ...
#
#
#  [[[-0.04907907 -0.05949699 -0.04046242 ... -0.04338294 -0.07385002
#     -0.0788655 ]
#    [-0.03229706 -0.06372897  0.02576963 ... -0.04632325 -0.05701261
#     -0.04912912]
#    [-0.05820591 -0.06621918 -0.05618161 ... -0.04338408 -0.07121816
#     -0.04315995]]
#
#   [[-0.05558569 -0.03582606 -0.07358789 ... -0.07917292 -0.04852177
#     -0.05490116]
#    [-0.05077389 -0.0486581  -0.05846856 ... -0.04217736 -0.05955088
#     -0.05475102]
#    [-0.05084298 -0.06786249 -0.07290001 ... -0.05901865 -0.0719587
#     -0.0589066 ]]
#
#   [[-0.0403803  -0.03512533 -0.06025381 ... -0.04984495 -0.06778404
#     -0.06509996]
#    [-0.0672142  -0.06449992 -0.0678869  ... -0.03224888 -0.05551754
#     -0.05361472]
#    [-0.06591436 -0.05465895 -0.06592688 ... -0.05644502 -0.07807696
#     -0.05650075]]
#
#   ...
#
#   [[-0.06668693 -0.04586267 -0.04459472 ... -0.05053503 -0.06783104
#     -0.05304109]
#    [-0.09746509 -0.05837437 -0.04406579 ... -0.04062998 -0.06749266
#     -0.06840117]
#    [-0.06883566 -0.07531179 -0.06259748 ... -0.04680647 -0.06186279
#     -0.06295232]]
#
#   [[-0.07089057 -0.07229923 -0.0446857  ... -0.0603572  -0.06062955
#     -0.06328221]
#    [-0.04116414 -0.05818138 -0.05273668 ... -0.04752373 -0.05589289
#     -0.06460498]
#    [-0.03246692 -0.07022471 -0.04950284 ... -0.04113501 -0.04522638
#     -0.05629764]]
#
#   [[-0.06970951 -0.05883185 -0.06855159 ... -0.04673328 -0.05456908
#     -0.08107375]
#    [-0.07978663 -0.04571025 -0.06731988 ... -0.06118274 -0.06276526
#     -0.06378963]
#    [-0.05384088 -0.07148184 -0.04855241 ... -0.08081263 -0.06547055
#     -0.05223944]]]
#
#
#  [[[-0.07738394 -0.06238877 -0.05613668 ... -0.05256619 -0.06777792
#     -0.05331807]
#    [-0.07663548 -0.06316616 -0.05221611 ... -0.05947183 -0.06073852
#     -0.05080761]
#    [-0.0756671  -0.05672457 -0.06291197 ... -0.04598313 -0.07358759
#     -0.06210688]]
#
#   [[-0.04173636 -0.07376339 -0.06139254 ... -0.04975125 -0.06062471
#     -0.06032082]
#    [-0.03104279 -0.05672258 -0.06073997 ... -0.0540863  -0.07212471
#     -0.05398216]
#    [-0.04305309 -0.04213766 -0.05747615 ... -0.03428432 -0.05878637
#     -0.04086622]]
#
#   [[-0.02618429 -0.05776595 -0.03818485 ... -0.05588436 -0.06299745
#     -0.05589118]
#    [-0.03725735 -0.03917637 -0.05126067 ... -0.07923901 -0.05724818
#     -0.04095503]
#    [-0.04301573 -0.06320272 -0.05406326 ... -0.06906419 -0.05515115
#     -0.05346099]]
#
#   ...
#
#   [[-0.06730437 -0.05346981 -0.05384488 ... -0.05960256 -0.05246083
#     -0.05287661]
#    [-0.06143334 -0.04579466 -0.04795444 ... -0.06666236 -0.06225698
#     -0.05984771]
#    [-0.0431297  -0.06758723 -0.04466826 ... -0.0637703  -0.05728825
#     -0.05239713]]
#
#   [[-0.04415062 -0.04867318 -0.06096929 ... -0.03564493 -0.07200378
#     -0.06713265]
#    [-0.04622016 -0.04129365 -0.05774066 ... -0.03284484 -0.0689659
#     -0.0501863 ]
#    [-0.04620928 -0.04927174 -0.04640345 ... -0.04813759 -0.05770412
#     -0.05961242]]
#
#   [[-0.04512918 -0.04673088 -0.04759109 ... -0.04744704 -0.07557536
#     -0.05444166]
#    [-0.03563023 -0.05529403 -0.06326011 ... -0.0728595  -0.06062812
#     -0.05584545]
#    [-0.04812931 -0.05468337 -0.06972387 ... -0.05448799 -0.06537239
#     -0.04981449]]]
#
#
#  [[[-0.07001074 -0.04644061 -0.0697473  ... -0.04608499 -0.05266984
#     -0.05788738]
#    [-0.0828311  -0.03586864 -0.05240477 ... -0.04597603 -0.05009617
#     -0.070139  ]
#    [-0.05862165 -0.06460387 -0.07194875 ... -0.04583869 -0.06467926
#     -0.06023443]]
#
#   [[-0.07341762 -0.06854747 -0.05968236 ... -0.03632046 -0.05869696
#     -0.05255532]
#    [-0.04516303 -0.06355814 -0.06045279 ... -0.05420128 -0.05244959
#     -0.04088144]
#    [-0.01325044 -0.05711666 -0.06389588 ... -0.05825173 -0.03764594
#     -0.05897063]]
#
#   [[-0.05659931 -0.05355986 -0.06457614 ... -0.03525964 -0.05528603
#     -0.06657333]
#    [-0.07365622 -0.05700599 -0.05591322 ... -0.03387253 -0.05765176
#     -0.06850175]
#    [-0.05274337 -0.07178289 -0.04137033 ... -0.04650301 -0.05788055
#     -0.06171362]]
#
#   ...
#
#   [[-0.06157505 -0.06814548 -0.07510668 ... -0.05155865 -0.07341895
#     -0.05458241]
#    [-0.07501964 -0.07077494 -0.05149831 ... -0.04826165 -0.06906016
#     -0.05770583]
#    [-0.06219676 -0.06352334 -0.03332442 ... -0.05348912 -0.05791123
#     -0.06006436]]
#
#   [[-0.06569928 -0.07197054 -0.05747188 ... -0.07748331 -0.05846325
#     -0.06025592]
#    [-0.05554998 -0.04542091 -0.05711029 ... -0.05469647 -0.05396448
#     -0.0551291 ]
#    [-0.04553657 -0.06405858 -0.04963721 ... -0.04915944 -0.06898545
#     -0.06924378]]
#
#   [[-0.03520318 -0.05648632 -0.06681483 ... -0.06074755 -0.05389855
#     -0.05597611]
#    [-0.06437384 -0.07929038 -0.06110963 ... -0.07908116 -0.07442692
#     -0.08337305]
#    [-0.05182723 -0.04733948 -0.05224689 ... -0.04497468 -0.07395872
#     -0.06310127]]]]

# %%
def define_name(i,j):
    if( i<500):
        feature_name="D:/sppnet_feature2/1/image%d_feature%d.jpg" %(i,j)
    elif(i<1000):
        feature_name="D:/sppnet_feature2/2/image%d_feature%d.jpg" %(i,j)
    elif(i<1500):
        feature_name="D:/sppnet_feature2/3/image%d_feature%d.jpg" %(i,j)
    elif(i<2000):
        feature_name="D:/sppnet_feature2/4/image%d_feature%d.jpg" %(i,j)
    elif(i<2500):
        feature_name="D:/sppnet_feature2/5/image%d_feature%d.jpg" %(i,j)
    elif(i<3000):
        feature_name="D:/sppnet_feature2/6/image%d_feature%d.jpg" %(i,j)
    elif(i<3500):
        feature_name="D:/sppnet_feature2/7/image%d_feature%d.jpg" %(i,j)
    elif(i<4000):
        feature_name="D:/sppnet_feature2/8/image%d_feature%d.jpg" %(i,j)
    elif(i<4500):
        feature_name="D:/sppnet_feature2/9/image%d_feature%d.jpg" %(i,j)
    elif(i<5000):
        feature_name="D:/sppnet_feature2/10/image%d_feature%d.jpg" %(i,j)
    elif(i<5500):
        feature_name="D:/sppnet_feature2/11/image%d_feature%d.jpg" %(i,j)
    elif(i<6000):
        feature_name="D:/sppnet_feature2/12/image%d_feature%d.jpg" %(i,j)
    elif(i<6500):
        feature_name="D:/sppnet_feature2/13/image%d_feature%d.jpg" %(i,j)
    elif(i<7000):
        feature_name="D:/sppnet_feature2/14/image%d_feature%d.jpg" %(i,j)
    elif(i<7500):
        feature_name="D:/sppnet_feature2/15/image%d_feature%d.jpg" %(i,j)
    elif(i<8000):
        feature_name="D:/sppnet_feature2/16/image%d_feature%d.jpg" %(i,j)
    elif(i<8500):
        feature_name="D:/sppnet_feature2/17/image%d_feature%d.jpg" %(i,j)
    elif(i<9000):
        feature_name="D:/sppnet_feature2/18/image%d_feature%d.jpg" %(i,j)
    elif(i<9500):
        feature_name="D:/sppnet_feature2/19/image%d_feature%d.jpg" %(i,j)
    elif(i<10000):
        feature_name="D:/sppnet_feature2/20/image%d_feature%d.jpg" %(i,j)
    elif(i<10500):
        feature_name="D:/sppnet_feature2/21/image%d_feature%d.jpg" %(i,j)
    elif(i<11000):
        feature_name="D:/sppnet_feature2/22/image%d_feature%d.jpg" %(i,j)
    elif(i<11500):
        feature_name="D:/sppnet_feature2/23/image%d_feature%d.jpg" %(i,j)
    elif(i<12000):
        feature_name="D:/sppnet_feature2/24/image%d_feature%d.jpg" %(i,j)
    elif(i<12500):
        feature_name="D:/sppnet_feature2/25/image%d_feature%d.jpg" %(i,j)
    elif(i<13000):
        feature_name="D:/sppnet_feature2/26/image%d_feature%d.jpg" %(i,j)
    elif(i<13500):
        feature_name="D:/sppnet_feature2/27/image%d_feature%d.jpg" %(i,j)
    elif(i<14000):
        feature_name="D:/sppnet_feature2/28/image%d_feature%d.jpg" %(i,j)
    elif(i<14500):
        feature_name="D:/sppnet_feature2/29/image%d_feature%d.jpg" %(i,j)
    elif(i<15000):
        feature_name="D:/sppnet_feature2/30/image%d_feature%d.jpg" %(i,j)
    elif(i<15500):
        feature_name="D:/sppnet_feature2/31/image%d_feature%d.jpg" %(i,j)
    elif(i<16000):
        feature_name="D:/sppnet_feature2/32/image%d_feature%d.jpg" %(i,j)
    elif(i<16500):
        feature_name="D:/sppnet_feature2/33/image%d_feature%d.jpg" %(i,j)
    else:
        feature_name="D:/sppnet_feature2/34/image%d_feature%d.jpg" %(i,j)
    return feature_name

# %%
for i in range(len(image_data)):
    image=image_data[i]
    image=cv2.resize(image,(224,224))
    image=np.expand_dims(image,0)
    sess.run(tf.global_variables_initializer())
    fe=sess.run(L5,feed_dict={X:image})
    fe1=np.squeeze(fe,axis=0)
    for j in range(256):    
        normalizedImg =np.zeros((14,14))
        normalizedImg = cv2.normalize(fe1[:,:,j],  normalizedImg, 0, 255, cv2.NORM_MINMAX)
        for x in range(14):
            for y in range(14):
                normalizedImg[x][y]=int(normalizedImg[x][y])
        
        feature_name=
        cv2.imwrite(feature_name,normalizedImg)
    print("image : %d"% i)

# %%
#visualize cnn feature
from tf_cnnvis import *
import os
# activation visualization
layers = ['r', 'p', 'c']
#test_data=cv2.resize() 224*224

with sess.as_default():
# with sess_graph_path = None, the default Session will be used for visualization.
    is_success = activation_visualization(sess_graph_path = None, value_feed_dict = {X : image}, 
                                          layers=layers, path_logdir=os.path.join("Log","ZFNet"), 
                                          path_outdir=os.path.join("Output","ZFNet"))
